# %%
import pyspark.sql.functions as F
spark.read.table('nyc_taxi.bronze.green_taxi').filter(F.col("trip_distance")==0).write.mode("overwrite").saveAsTable(f"nyc_taxi.quranatine.taxi_zero_miles_{current_timestamp}")
